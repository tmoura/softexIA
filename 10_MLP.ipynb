# %% [markdown]
# <a href="https://colab.research.google.com/github/tmoura/softexIA/blob/main/10_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
import pandas as pd
from sklearn.neural_network import MLPClassifier

url = "https://raw.githubusercontent.com/tmoura/machinelearning/master/iris.data"

# Carregar base de dados
dataset = pd.read_csv(url, header=None)

columns = len(dataset.columns)

y = dataset[0] # extrai a primeira coluna, que é o label
X = dataset.loc[:,1:columns-1]

X.head(5) # Mostra os 5 primeiros dados da tabela

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y) # 80% treino e 20% teste

model = MLPClassifier(hidden_layer_sizes=(3,2), activation='tanh',max_iter=2000)
model = model.fit(X_train, y_train)

#print(model)

# %%
result = model.predict(X_test)
acc = metrics.accuracy_score(result, y_test)
show = round(acc * 100)
print("{}%".format(show))

print(list(result))
print(list(y_test))

# %% [markdown]
# ## Rede Criada<br>![Captura de tela de 2020-11-13 11-29-40.png](data:image/png;base64,...)

# %%
###############
# Parâmetros da Rede
###############

print("Número de classes:",model.classes_,"\n")
print("Número de camadas:",model.n_layers_,"\n")
print("Número de saídas:",model.n_outputs_,"\n")

print("Tamanho do vetor de pesos:",len(model.coefs_),"\n")
print("Pesos da camada de entrada:\n",model.coefs_[0],"\n")

print("Tamanho do vetor dos limiares (bias):",len(model.intercepts_),"\n")
print("Pesos omega (limiar):\n",model.intercepts_[0],"\n")

# %%
import pandas as pd
import seaborn as sns # API de visualização

url = "https://raw.githubusercontent.com/tmoura/machinelearning/master/iris.data"

# Carregar base de dados
dataset = pd.read_csv(url, header=None)

sns.pairplot(data=dataset, vars=(1,2,3,4), hue=0 )
